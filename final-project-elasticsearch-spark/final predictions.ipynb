# %%
from recommend import display_similar

# %%
import pandas as pd
movies_df = pd.read_csv("ml-latest/movies.csv")
movies_df['title'] = movies_df['title'].str.lower()

def search(title):
    return movies_df[movies_df['title'].str.contains(title)]

# %%
search('psycho')
# Out:
#        movieId                                              title  \
# 1193      1219                                      psycho (1960)
# 2305      2389                                      psycho (1998)
# 2817      2902                                   psycho ii (1983)
# 2818      2903                                  psycho iii (1986)
# 3445      3535                             american psycho (2000)
# 3739      3830                          psycho beach party (2000)
# 9357     27473       american psycho ii: all american girl (2002)
# 12296    56253             symbiopsychotaxiplasm: take one (1968)
# 13455    66105           psychomania (death wheelers, the) (1973)
# 19825    97306                           seven psychopaths (2012)
# 19992    98004           single white female 2: the psycho (2005)
# 20609   100229                             psychopath, the (1966)
# 21474   103454  batman unmasked: the psychology of the dark kn...
# ...

# %%
display_similar(1219, num=5)
# Out:
# Get similar movies for:
# Psycho
#
# People who liked this movie also liked these:
#
# Charm with score: 0.99992234
#
# Death of a Gentleman with score: 0.99992234
#
# How Not to Work & Claim Benefits... (and Other Useful Information for Wasters) with score: 0.9999223
#
# Correcting Christmas with score: 0.9999223
#
# Kaksparsh with score: 0.9999223
